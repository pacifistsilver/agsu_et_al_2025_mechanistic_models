# %%
import arviz as az
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pymc as pm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import arviz as az
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 import pymc as pm
#
# File c:\Users\danie\miniconda3\Lib\site-packages\arviz\__init__.py:66
#      63 info += _status + "\n"
#      65 try:
# ---> 66     from arviz_plots import *
#      67     import arviz_plots as plots
#      69     _status = (
#      70         f"arviz_plots {plots.__version__} available, "
#      71         "exposing its functions as part of the `arviz` namespace"
#      72     )
#
# File c:\Users\danie\miniconda3\Lib\site-packages\arviz_plots\__init__.py:37
#      34 import matplotlib as mpl
#      36 _arviz_style_path = os.path.join(os.path.dirname(__file__), "styles")
# ---> 37 mplstyle.core.USER_LIBRARY_PATHS.append(_arviz_style_path)
#      38 mplstyle.core.reload_library()
#      40 # adds perceptually uniform grey scale from colorcet
#
# AttributeError: module 'matplotlib.style' has no attribute 'core'

# %%
data = np.random.normal(loc=0, scale=1, size=1000)
def normal_sim(rng, a, b, size=1000):
    return rng.normal(a, b, size=size)

# %%
with pm.Model() as example:
    a = pm.Normal("a", mu=0, sigma=5)
    b = pm.HalfNormal("b", sigma=1)
    s = pm.Simulator("s", normal_sim, params=(a, b), sum_stat="sort", epsilon=1, observed=data)

    idata = pm.sample_smc()
    idata.extend(pm.sample_posterior_predictive(idata))
# Out:
# Initializing SMC sampler...
# c:\Users\danie\miniconda3\Lib\site-packages\pytensor\link\numba\dispatch\basic.py:234: UserWarning: Numba will use object mode to run Simulator_s_rv{"(),()->()"}'s perform method. Set `pytensor.config.compiler_verbose = True` to see more details.
#   warnings.warn(
# Sampling 8 chains in 8 jobs
# Output()

# %%
az.plot_trace(idata, kind="rank_vlines")
az.summary(idata, kind="stats")

# %%
az.plot_ppc(idata, num_pp_samples=500)
